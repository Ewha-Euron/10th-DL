# %% [markdown]
# # **U-Net 모델 구현**
#
# ✅ 아래 코드는 PyTorch로 작성한 간단한 U-Net 모델입니다.
#
# ✅ 주요 목표: 작은 이미지 세트로 segmentation 학습을 테스트하기!
#
# ✅ 특징: 업샘플링(deconv/upsample 선택 가능), 입력 스케일링, Gaussian noise 추가, 배치 정규화 적용

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

# --- 작은 U-Net 정의 ---
class UNetSmall(nn.Module):
    def __init__(self, upsample_mode='deconv', net_scaling=None, edge_crop=0, gaussian_noise_std=0.1):
        super().__init__()
        self.net_scaling = net_scaling
        self.edge_crop = edge_crop
        self.gaussian_noise_std = gaussian_noise_std
        self.upsample_mode = upsample_mode

         # Convolution Block: Conv -> ReLU -> Conv -> ReLU
        def conv_block(in_c, out_c):
            return nn.Sequential(
                nn.Conv2d(in_c, out_c, 3, padding=1),
                nn.ReLU(inplace=True),
                nn.Conv2d(out_c, out_c, 3, padding=1),
                nn.ReLU(inplace=True)
            )

        # 인코더 부분 목표 -> 128 까지!
        self.enc1 = conv_block(3, 16)
        self.enc2 = conv_block(16, 32)
        self.enc3 = conv_block(32, 64)
        self.enc4 = conv_block(64, 128)
        # Bottleneck
        self.center = conv_block(128, 128)
        self.pool = nn.MaxPool2d(2)


        # 업샘플링 부분 정의 (deconv 또는 upsample+conv) 로
        if upsample_mode == 'deconv':
            def upsample_layer(in_c, out_c):
                return nn.ConvTranspose2d(in_c, out_c, 2, stride=2)
        else:
            def upsample_layer(in_c, out_c):
                return nn.Sequential(
                    nn.Upsample(scale_factor=2, mode='nearest'),
                    nn.Conv2d(in_c, out_c, 1)
                )
        # 디코더 부분
        self.up4 = upsample_layer(128, 64)
        self.dec4 = conv_block(192, 64)
        self.up3 = upsample_layer(64, 32)
        self.dec3 = conv_block(96, 32)
        self.up2 = upsample_layer(32, 16)
        self.dec2 = conv_block(48, 16)
        self.up1 = upsample_layer(16, 8)
        self.dec1 = conv_block(24, 8)

        # 최종 출력: 1채널(segmentation mask)
        self.final = nn.Conv2d(8, 1, 1)

    def forward(self, x):
        if self.net_scaling:
        # 입력 스케일링
            x = F.avg_pool2d(x, self.net_scaling)
        # Gaussian noise 추가
        if self.gaussian_noise_std:
            noise = torch.randn_like(x) * self.gaussian_noise_std
            x = x + noise

        # 배치 정규화 적용
        x = F.batch_norm(x, running_mean=None, running_var=None, training=True)

        # 인코더
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))
        # Bottleneck
        center = self.center(self.pool(e4))

        # 디코더 + Skip Connection
        d4 = self.up4(center)
        d4 = torch.cat([d4, e4], dim=1)
        d4 = self.dec4(d4)

        d3 = self.up3(d4)
        d3 = torch.cat([d3, e3], dim=1)
        d3 = self.dec3(d3)

        d2 = self.up2(d3)
        d2 = torch.cat([d2, e2], dim=1)
        d2 = self.dec2(d2)

        d1 = self.up1(d2)
        d1 = torch.cat([d1, e1], dim=1)
        d1 = self.dec1(d1)

        out = self.final(d1)
        out = torch.sigmoid(out)
         # Crop + Pad
        if self.edge_crop > 0:
            out = out[:, :, self.edge_crop:-self.edge_crop, self.edge_crop:-self.edge_crop]
            out = F.pad(out, (self.edge_crop, self.edge_crop, self.edge_crop, self.edge_crop))
        # Upsample 다시 확대
        if self.net_scaling:
            out = F.interpolate(out, scale_factor=self.net_scaling, mode='nearest')

        return out

# %% [markdown]
# ## **학습용 데이터 생성하기**

# %%
batch_size = 32
x = torch.randn(batch_size, 3, 128, 128)  # RGB 이미지
y = (torch.rand(batch_size, 1, 128, 128) > 0.5).float()  # 랜덤 이진 마스크

dataset = TensorDataset(x, y)
loader = DataLoader(dataset, batch_size=2, shuffle=True)

# %% [markdown]
# ## **데이터 시각화**

# %%
import matplotlib.pyplot as plt
# 첫 번째 이미지를 시각화
sample_x = x[0]
sample_y = y[0]

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(sample_x.permute(1, 2, 0).numpy())
plt.title('Input Image')

plt.subplot(1, 2, 2)
plt.imshow(sample_y.squeeze().numpy(), cmap='gray')
plt.title('Ground Truth Mask')
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-3.7122624..4.200616].

# %% [markdown]
# ## **모델 선언 및 학습**

# %%
# --- 모델 선언 및 학습 ---
model = UNetSmall(upsample_mode='deconv', net_scaling=None, edge_crop=0)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.BCELoss()

# 간단히 30 epoch만
for epoch in range(10):
    model.train()
    total_loss = 0
    for xb, yb in loader:
        pred = model(xb)
        loss = criterion(pred, yb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch {epoch+1}, Loss: {total_loss/len(loader):.4f}")
# Out:
# Epoch 1, Loss: 0.6940
# Epoch 2, Loss: 0.6932
# Epoch 3, Loss: 0.6932
# Epoch 4, Loss: 0.6932
# Epoch 5, Loss: 0.6931
# Epoch 6, Loss: 0.6931
# Epoch 7, Loss: 0.6931
# Epoch 8, Loss: 0.6931
# Epoch 9, Loss: 0.6931
# Epoch 10, Loss: 0.6931

# %% [markdown]
# ## **아래 주석을 풀고 U-Net 모델에 대해 간단히 설명해주세요 😀**

# %% [markdown]
# [답변] <br>
# U-Net: **의료 이미지 분할**을 위해 설계된 CNN 구조
# 핵심 구조:
# - 인코더: Conv + MaxPool을 반복하며 특징을 추출하고 공간 해상도를 줄임
# - 보틀넥(병목): 가장 압축된 특징 표현
# - 디코더: 업샘플링으로 해상도를 복원
# - Skip Connection: 인코더의 각 레벨 특징맵을 디코더에 직접 연결(concatenate)하여, 위치 정보(세부 공간 정보)가 손실되지 않도록 보존
#   - Skip Connection 덕분에 경계선/엣지 등 세밀한 위치 정보를 잘 살려서 픽셀 단위 예측 정확도가 높음

# %% [markdown]
# ## **아래 주석을 풀고 DeepLabv1, v2, v3. v3+  모델에 대해 각각 간단히 설명해주세요 🐶**

# %% [markdown]
# [답변]
#
# [DeepLab v1] <br>
# - Dilated(Atrous) Convolution 도입: 필터 내부에 간격(dilation)을 두어, 파라미터 수 증가 없이 수용 영역(Receptive Field)을 넓힘
# - CRF(Conditional Random Field) 후처리: CNN 출력이 뭉툭한 경계를 CRF로 정교하게 다듬음
# - Fully Connected CRF를 후처리로 사용해 픽셀 간 관계를 모델링
#
# <br>
#
# [DeepLab v2]
# - ASPP(Atrous Spatial Pyramid Pooling) 도입: 서로 다른 dilation rate(6, 12, 18, 24)의 Atrous Conv를 병렬로 적용하여 다양한 스케일의 객체를 동시에 포착
# - 백본을 ResNet으로 교체하여 성능 향상
# - 여전히 CRF 후처리 사용
# <br>
#
# [DeepLab v3]
# - ASPP 개선: Batch Normalization 추가, Global Average Pooling 브랜치 추가
# - CRF 후처리를 제거하고도 좋은 성능 달성
# - 더 큰 dilation rate 사용 및 출력 스트라이드 조절로 해상도-정확도 트레이드오프 개선
# <br>
#
# [DeepLab v3+]
# - 인코더-디코더 구조 추가: v3의 ASPP 인코더에 디코더 모듈을 붙임
# - 인코더의 저수준 특징을 디코더에서 활용 → 경계 부분 정확도 개선
# - 백본으로 Xception 구조 사용 (Depthwise Separable Convolution으로 경량화)
# - v3 대비 경계선 복원이 훨씬 정밀해짐
