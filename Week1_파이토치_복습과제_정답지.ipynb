# %% [markdown]
# # **1주차 복습과제 해설 및 답안**
# 문제의 출제 의도와 예시 답안을 확인해 보세요.

# %% [markdown]
# ## **문제 1: 텐서(Tensor) 기초 조작 (총 10점)**

# %% [markdown]
# ### **1-1. 텐서 생성 및 차원 변경 (5점)**

# %%
import torch

### 예시 답안 ###
temp_tensor = torch.tensor([1, 2, 3, 4, 5, 6])
reshaped_tensor = temp_tensor.view(2, 3) # reshape(2, 3) 도 정답 인정

print(reshaped_tensor)
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %% [markdown]
# ### **1-2. 디바이스 할당 (5점)**

# %%
### 예시 답안 ###
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# 한 줄 요약 버전도 정답 인정: device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

tensor_on_device = reshaped_tensor.to(device)
print(f"할당된 디바이스: {tensor_on_device.device}")

# %% [markdown]
# ## **문제 2: 커스텀 데이터셋 구축 (총 10점)**

# %% [markdown]
# ### **2-1. 빈칸 채우기 (10점)**
# - `__init__`: 필요한 변수 선언 및 데이터 초기화
# - `__len__`: 데이터셋 총 크기 반환
# - `__getitem__`: 특정 인덱스의 데이터(샘플, 레이블) 반환

# %%
from torch.utils.data import Dataset
import pandas as pd

class MyCustomDataset(Dataset):
    ### 예시 답안 ###
    def __init__(self, csv_file):
        self.data = pd.read_csv(csv_file)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = torch.tensor(self.data.iloc[idx, 0:-1].values).float()
        label = torch.tensor(self.data.iloc[idx, -1]).long()
        return sample, label

print("클래스 선언 완료!")

# %% [markdown]
# ## **문제 3: Sequential을 이용한 모델 정의 (총 10점)**

# %%
import torch.nn as nn

class SimpleMLP(nn.Module):
    def __init__(self, input_size, output_size):
        super(SimpleMLP, self).__init__()
        ### 예시 답안 ###
        self.network = nn.Sequential(
            nn.Linear(in_features=input_size, out_features=20),
            nn.ReLU(),  # inplace=True 옵션 포함 여부 무관
            nn.Linear(in_features=20, out_features=output_size)
        )

    def forward(self, x):
        return self.network(x)

model = SimpleMLP(10, 2)
print(model)

# %% [markdown]
# ## **문제 4: 모델 훈련 루프 5단계 (총 10점)**

# %%
def train_loop(dataloader, model, criterion, optimizer):
    # for x_batch, y_batch in dataloader:
        
        ### 예시 답안 ###
        # 1. 기울기 초기화
        optimizer.zero_grad()
        
        # 2. 모델 예측(출력 계산)
        # y_pred = model(x_batch)

        # 3. 오차 계산
        # loss = criterion(y_pred, y_batch)

        # 4. 역전파 학습 기울기 자동 계산
        # loss.backward()
        
        # 5. 기울기 업데이트
        # optimizer.step()
        pass
